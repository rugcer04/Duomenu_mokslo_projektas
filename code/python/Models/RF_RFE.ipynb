# %% [markdown]
# # Bibliotekos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from scipy import stats

from sklearn.inspection import permutation_importance
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

from sklearn.feature_selection import RFECV
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# # Duomenys

# %%
data = pd.read_csv("../datasets_prep/dm_project_dataset.csv")
data['observationTime'] = pd.to_datetime(data['observationTime'])
data.columns
# Out:
# Index(['observationTime', 'absorbing_aerosol_index',
#        'NO2_column_number_density', 'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'tropopause_pressure',
#        'H2O_column_number_density', 'BrO', 'BrO_Error', 'NO2', 'NO2_Error',
#        'O3', 'O3_Error', 'pm10', 'pm2p5', 'sia', 'nmvoc', 'dust', 'nh3',
#        'pans', 'tp', 't2m', 'airTemperature', 'seaLevelPressure',
#        'relativeHumidity', 'missforest_precipitation', 'xgb_cloudCover',
#        'feelsLikeTemperature_fixed', 'windSpeed_fixed', 'windGust_fixed',
#        'windDirection_fixed'],
#       dtype='object')

# %%
data = data.drop(columns=['BrO_Error', 'NO2_Error', 'O3_Error', 't2m'])
data['month'] = data['observationTime'].dt.month
data['day_of_year'] = data['observationTime'].dt.dayofyear
data['day_of_week'] = data['observationTime'].dt.dayofweek

# %%
data.columns
# Out:
# Index(['observationTime', 'absorbing_aerosol_index',
#        'NO2_column_number_density', 'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'tropopause_pressure',
#        'H2O_column_number_density', 'BrO', 'NO2', 'O3', 'pm10', 'pm2p5', 'sia',
#        'nmvoc', 'dust', 'nh3', 'pans', 'tp', 'airTemperature',
#        'seaLevelPressure', 'relativeHumidity', 'missforest_precipitation',
#        'xgb_cloudCover', 'feelsLikeTemperature_fixed', 'windSpeed_fixed',
#        'windGust_fixed', 'windDirection_fixed', 'month', 'day_of_year',
#        'day_of_week'],
#       dtype='object')

# %%
data.head(5)
# Out:
#   observationTime  absorbing_aerosol_index  NO2_column_number_density  \
# 0      2018-07-01                -1.016247                   0.000075
# 1      2018-07-02                -0.800622                   0.000079
# 2      2018-07-03                -0.621235                   0.000077
# 3      2018-07-04                -0.659180                   0.000072
# 4      2018-07-05                -1.010234                   0.000079
#
#    stratospheric_NO2_column_number_density  NO2_slant_column_number_density  \
# 0                                 0.000062                         0.000193
# 1                                 0.000066                         0.000196
# 2                                 0.000062                         0.000203
# 3                                 0.000065                         0.000146
# 4                                 0.000067                         0.000198
#
#    tropopause_pressure  H2O_column_number_density           BrO           NO2  \
# 0            22057.926                1136.782022  4.376100e+13  3.627587e+15
# 1            22067.760                1229.531736  3.946727e+13  3.795988e+15
# 2            19219.670                1314.680602  4.465846e+13  4.526218e+15
# 3            19219.450                1824.427700  4.888972e+13  4.149200e+15
# 4            19218.373                1257.064200  4.093649e+13  3.959891e+15
#
#            O3  ...  relativeHumidity  missforest_precipitation  \
# 0  332.670633  ...         72.791667                       9.1
# 1  339.679410  ...         94.000000                      11.9
# 2  361.533268  ...         90.041667                      10.0
# 3  343.308865  ...         88.291667                      13.9
# 4  311.500626  ...         70.208333                       0.0
#
#    xgb_cloudCover  feelsLikeTemperature_fixed  windSpeed_fixed  \
# 0       89.375000                   10.933333         3.762500
# 1       91.500000                   10.429167         2.516667
# 2       89.375000                   13.387500         2.537500
# 3       88.333333                   13.591667         2.358333
# 4       66.000000                   16.291667         1.283333
#
#    windGust_fixed  windDirection_fixed  month  day_of_year  day_of_week
# 0            13.9                356.0      7          182            6
# 1             7.0                327.0      7          183            0
# 2             8.3                271.0      7          184            1
# 3             8.7                288.0      7          185            2
# 4             6.1                293.0      7          186            3
#
# [5 rows x 30 columns]

# %% [markdown]
# # Random Forest realizacija

# %% [markdown]
# ## Požymių sukūrimas

# %% [markdown]
# ### Vėlavimai

# %%
def lags_fun(column_name, lag_value, data):
    
    new_col_name = f"{column_name}_lag-{lag_value}"
    data.loc[:, new_col_name] = data[column_name].shift(lag_value)

# %%
lags_info = {
    # DALELES
    'absorbing_aerosol_index': [8, 19],
    'NO2_column_number_density': [1, 2, 3],
    'stratospheric_NO2_column_number_density': [1, 3, 7],
    'NO2_slant_column_number_density': [1, 2],
    'tropopause_pressure': [1],
    'H2O_column_number_density': [1, 2],
    'NO2': [1, 4, 9],
    'dust': [1, 4],
    'sia': [11],
    'pm2p5': [1, 11],
    'pans': [10, 18],
    'nmvoc': [1, 2],
    'nh3': [1, 11],
    'pm10': [1, 11],

    # METEO
    'airTemperature': [1, 3, 9, 10],
    'seaLevelPressure': [1, 2],
    'relativeHumidity': [1, 2],
    'xgb_cloudCover': [1, 2],
    'windSpeed_fixed': [1, 2, 3],
    'windGust_fixed': [1, 2],
    'windDirection_fixed': [4, 10]
}

for col, lags in lags_info.items():
    if isinstance(lags, list):
        for lag in lags:
            lags_fun(col, lag, data)
    else:
        lags_fun(col, lags, data)

# %%
data['target_precipitation'] = data['missforest_precipitation'].shift(-1)

# %% [markdown]
# ### Rolling window

# %%
def rolling_window_fun(column_name, window_value, data):

    new_col_name = f"{column_name}_window-{window_value}"
    data.loc[:, new_col_name] = data[column_name].rolling(window=window_value).mean().shift(1)

# %%
window_info = {
    'absorbing_aerosol_index': [8],
    'NO2_column_number_density': [3, 2],
    'stratospheric_NO2_column_number_density': [3, 5, 7],
    'NO2_slant_column_number_density': [2],
    'tropopause_pressure': [1],
    'H2O_column_number_density': [2],
    'NO2': [3, 5, 7],
    'dust': [4, 6, 8],
    'sia': [11],
    'pm2p5': [11],
    'pans': [10],
    'nmvoc': [3, 5],
    'nh3': [2, 4],
    'pm10': [5]
}

for col, windows in window_info.items():
    if isinstance(windows, list):
        for window in windows:
            rolling_window_fun(col, window, data)
    else:
        rolling_window_fun(col, windows, data)

# %%
data_clean = data.dropna()

# %%
data_clean.columns
# Out:
# Index(['observationTime', 'absorbing_aerosol_index',
#        'NO2_column_number_density', 'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'tropopause_pressure',
#        'H2O_column_number_density', 'BrO', 'NO2', 'O3', 'pm10', 'pm2p5', 'sia',
#        'nmvoc', 'dust', 'nh3', 'pans', 'tp', 'airTemperature',
#        'seaLevelPressure', 'relativeHumidity', 'missforest_precipitation',
#        'xgb_cloudCover', 'feelsLikeTemperature_fixed', 'windSpeed_fixed',
#        'windGust_fixed', 'windDirection_fixed', 'month', 'day_of_year',
#        'day_of_week', 'absorbing_aerosol_index_lag-8',
#        'absorbing_aerosol_index_lag-19', 'NO2_column_number_density_lag-1',
#        'NO2_column_number_density_lag-2', 'NO2_column_number_density_lag-3',
#        'stratospheric_NO2_column_number_density_lag-1',
#        'stratospheric_NO2_column_number_density_lag-3',
#        'stratospheric_NO2_column_number_density_lag-7',
#        'NO2_slant_column_number_density_lag-1',
#        'NO2_slant_column_number_density_lag-2', 'tropopause_pressure_lag-1',
#        'H2O_column_number_density_lag-1', 'H2O_column_number_density_lag-2',
#        'NO2_lag-1', 'NO2_lag-4', 'NO2_lag-9', 'dust_lag-1', 'dust_lag-4',
#        'sia_lag-11', 'pm2p5_lag-1', 'pm2p5_lag-11', 'pans_lag-10',
#        'pans_lag-18', 'nmvoc_lag-1', 'nmvoc_lag-2', 'nh3_lag-1', 'nh3_lag-11',
#        'pm10_lag-1', 'pm10_lag-11', 'airTemperature_lag-1',
#        'airTemperature_lag-3', 'airTemperature_lag-9', 'airTemperature_lag-10',
#        'seaLevelPressure_lag-1', 'seaLevelPressure_lag-2',
#        'relativeHumidity_lag-1', 'relativeHumidity_lag-2',
#        'xgb_cloudCover_lag-1', 'xgb_cloudCover_lag-2', 'windSpeed_fixed_lag-1',
#        'windSpeed_fixed_lag-2', 'windSpeed_fixed_lag-3',
#        'windGust_fixed_lag-1', 'windGust_fixed_lag-2',
#        'windDirection_fixed_lag-4', 'windDirection_fixed_lag-10',
#        'target_precipitation', 'absorbing_aerosol_index_window-8',
#        'NO2_column_number_density_window-3',
#        'NO2_column_number_density_window-2',
#        'stratospheric_NO2_column_number_density_window-3',
#        'stratospheric_NO2_column_number_density_window-5',
#        'stratospheric_NO2_column_number_density_window-7',
#        'NO2_slant_column_number_density_window-2',
#        'tropopause_pressure_window-1', 'H2O_column_number_density_window-2',
#        'NO2_window-3', 'NO2_window-5', 'NO2_window-7', 'dust_window-4',
#        'dust_window-6', 'dust_window-8', 'sia_window-11', 'pm2p5_window-11',
#        'pans_window-10', 'nmvoc_window-3', 'nmvoc_window-5', 'nh3_window-2',
#        'nh3_window-4', 'pm10_window-5'],
#       dtype='object')

# %% [markdown]
# ## Požymių atrinkimas ir aibių sudarymas

# %% [markdown]
# ### Aibių sudarymas I

# %%
train_end = '2024-02-01'
val_end = '2025-02-01'

train = data_clean[data_clean['observationTime'] < train_end]
val = data_clean[(data_clean['observationTime'] >= train_end) & (data_clean['observationTime'] <= val_end)]
test  = data_clean[data_clean['observationTime'] > val_end]

print(f"Train: {train.shape}, nuo {train['observationTime'].min()} iki {train['observationTime'].max()}")
print(f"Val: {val.shape}, nuo {val['observationTime'].min()} iki {val['observationTime'].max()}")
print(f"Test:  {test.shape},  nuo {test['observationTime'].min()} iki {test['observationTime'].max()}")
# Out:
# Train: (2022, 100), nuo 2018-07-20 00:00:00 iki 2024-01-31 00:00:00
# Val: (367, 100), nuo 2024-02-01 00:00:00 iki 2025-02-01 00:00:00
# Test:  (363, 100),  nuo 2025-02-02 00:00:00 iki 2026-01-30 00:00:00

# %%
target = 'target_precipitation'
drop_cols = ['observationTime', target]

X_train = train.drop(columns=drop_cols)
y_train = train[target]

X_val = val.drop(columns=drop_cols)
y_val = val[target]

X_test = test.drop(columns=drop_cols)
y_test = test[target]

# %%
clf = RandomForestRegressor(random_state=123)
tscv = TimeSeriesSplit(n_splits=5)

rfecv = RFECV(
    estimator=clf,
    step=3,
    cv=tscv,
    scoring="neg_mean_squared_error", 
    min_features_to_select=10,
    n_jobs=-1
)

rfecv.fit(X_train, y_train)

selected_features = list(X_train.columns[rfecv.support_])
print(f"Optimalus požymių skaičius: {rfecv.n_features_}")
print(f"Geriausi požymiai: {selected_features}")

plt.figure(figsize=(10, 6))

n_features_range = range(1, len(rfecv.cv_results_['mean_test_score']) + 1)
mean_scores = rfecv.cv_results_['mean_test_score']
std_scores = rfecv.cv_results_['std_test_score']

plt.errorbar(
    x=n_features_range,
    y=mean_scores,
    yerr=std_scores,
    fmt='-o', color='#00CCFF', ecolor='#FF9900', capsize=3, elinewidth=1, markeredgewidth=1
)

plt.title(f"Optimalaus požymių skaičiaus paieška (Optimalus n={rfecv.n_features_})")
plt.xlabel("Pasirinktų požymių skaičius")
plt.ylabel("Vidutinis neg_MSE")
plt.grid(alpha=0.3)
plt.axvline(x=rfecv.n_features_, color='red', linestyle='--', label='Optimalus kiekis')
plt.legend()
plt.show()
# Out:
# Optimalus požymių skaičius: 56
# Geriausi požymiai: ['absorbing_aerosol_index', 'NO2_column_number_density', 'tropopause_pressure', 'H2O_column_number_density', 'BrO', 'pm10', 'pm2p5', 'dust', 'pans', 'tp', 'airTemperature', 'seaLevelPressure', 'relativeHumidity', 'missforest_precipitation', 'xgb_cloudCover', 'feelsLikeTemperature_fixed', 'windGust_fixed', 'windDirection_fixed', 'absorbing_aerosol_index_lag-8', 'absorbing_aerosol_index_lag-19', 'stratospheric_NO2_column_number_density_lag-3', 'stratospheric_NO2_column_number_density_lag-7', 'NO2_slant_column_number_density_lag-1', 'tropopause_pressure_lag-1', 'H2O_column_number_density_lag-1', 'H2O_column_number_density_lag-2', 'NO2_lag-4', 'NO2_lag-9', 'dust_lag-1', 'pm2p5_lag-1', 'pm2p5_lag-11', 'pans_lag-10', 'nh3_lag-11', 'pm10_lag-11', 'airTemperature_lag-1', 'airTemperature_lag-9', 'airTemperature_lag-10', 'relativeHumidity_lag-1', 'relativeHumidity_lag-2', 'windSpeed_fixed_lag-1', 'windSpeed_fixed_lag-3', 'windGust_fixed_lag-1', 'windGust_fixed_lag-2', 'windDirection_fixed_lag-10', 'absorbing_aerosol_index_window-8', 'stratospheric_NO2_column_number_density_window-7', 'tropopause_pressure_window-1', 'H2O_column_number_density_window-2', 'NO2_window-7', 'dust_window-4', 'dust_window-6', 'sia_window-11', 'pans_window-10', 'nh3_window-2', 'nh3_window-4', 'pm10_window-5']

# %%
data_clean = data_clean[selected_features + ['observationTime', 'target_precipitation']].copy()

# %% [markdown]
# ### Aibių sudarymas II

# %%
train_end = '2024-02-01'
val_end = '2025-02-01'

train = data_clean[data_clean['observationTime'] < train_end]
val = data_clean[(data_clean['observationTime'] >= train_end) & (data_clean['observationTime'] <= val_end)]
test  = data_clean[data_clean['observationTime'] > val_end]

print(f"Train: {train.shape}, nuo {train['observationTime'].min()} iki {train['observationTime'].max()}")
print(f"Val: {val.shape}, nuo {val['observationTime'].min()} iki {val['observationTime'].max()}")
print(f"Test:  {test.shape},  nuo {test['observationTime'].min()} iki {test['observationTime'].max()}")
# Out:
# Train: (2022, 58), nuo 2018-07-20 00:00:00 iki 2024-01-31 00:00:00
# Val: (367, 58), nuo 2024-02-01 00:00:00 iki 2025-02-01 00:00:00
# Test:  (363, 58),  nuo 2025-02-02 00:00:00 iki 2026-01-30 00:00:00

# %%
target = 'target_precipitation'
drop_cols = ['observationTime', target]

X_train = train.drop(columns=drop_cols)
y_train = train[target]

X_val = val.drop(columns=drop_cols)
y_val = val[target]

X_test = test.drop(columns=drop_cols)
y_test = test[target]

# %% [markdown]
# ### Realizacija

# %%
X_train.columns
# Out:
# Index(['absorbing_aerosol_index', 'NO2_column_number_density',
#        'tropopause_pressure', 'H2O_column_number_density', 'BrO', 'pm10',
#        'pm2p5', 'dust', 'pans', 'tp', 'airTemperature', 'seaLevelPressure',
#        'relativeHumidity', 'missforest_precipitation', 'xgb_cloudCover',
#        'feelsLikeTemperature_fixed', 'windGust_fixed', 'windDirection_fixed',
#        'absorbing_aerosol_index_lag-8', 'absorbing_aerosol_index_lag-19',
#        'stratospheric_NO2_column_number_density_lag-3',
#        'stratospheric_NO2_column_number_density_lag-7',
#        'NO2_slant_column_number_density_lag-1', 'tropopause_pressure_lag-1',
#        'H2O_column_number_density_lag-1', 'H2O_column_number_density_lag-2',
#        'NO2_lag-4', 'NO2_lag-9', 'dust_lag-1', 'pm2p5_lag-1', 'pm2p5_lag-11',
#        'pans_lag-10', 'nh3_lag-11', 'pm10_lag-11', 'airTemperature_lag-1',
#        'airTemperature_lag-9', 'airTemperature_lag-10',
#        'relativeHumidity_lag-1', 'relativeHumidity_lag-2',
#        'windSpeed_fixed_lag-1', 'windSpeed_fixed_lag-3',
#        'windGust_fixed_lag-1', 'windGust_fixed_lag-2',
#        'windDirection_fixed_lag-10', 'absorbing_aerosol_index_window-8',
#        'stratospheric_NO2_column_number_density_window-7',
#        'tropopause_pressure_window-1', 'H2O_column_number_density_window-2',
#        'NO2_window-7', 'dust_window-4', 'dust_window-6', 'sia_window-11',
#        'pans_window-10', 'nh3_window-2', 'nh3_window-4', 'pm10_window-5'],
#       dtype='object')

# %%
rf_default = RandomForestRegressor(random_state=123)
rf_default.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=123)

# %%
rf_default_pred_val = rf_default.predict(X_val)

# %% [markdown]
# ### Metrikos

# %%
def metrics_fun(y_val_true, rf_pred_val):
    print(f'R^2:  {r2_score(y_val_true, rf_pred_val)}')
    print(f'MAE:  {mean_absolute_error(y_val_true, rf_pred_val)}')
    print(f'RMSE: {np.sqrt(mean_squared_error(y_val_true, rf_pred_val))}')
    # print(f'MAPE: {mean_absolute_percentage_error(y_val_true, rf_pred_val)}')

    corr, p_value = stats.spearmanr(y_val_true, rf_pred_val)
    print(f"r_s:  {corr}")

# %% [markdown]
# Globalaus modelio paklaidos - validavimo aibė

# %%
metrics_fun(y_val, X_val['tp'])
# Out:
# R^2:  0.5026324749895323
# MAE:  1.4685700168000633
# RMSE: 3.40532484561435
# r_s:  0.7378103776223065

# %% [markdown]
# RF modelio paklaidos

# %%
metrics_fun(y_val, rf_default_pred_val)
# Out:
# R^2:  0.3721872675821194
# MAE:  1.581553315410576
# RMSE: 3.825911273380015
# r_s:  0.7037695204910841

# %%
len(rf_default_pred_val)
# Out:
# 367

# %% [markdown]
# ### Vizualizacija

# %%
# plot_df = val[['observationTime', 'target_precipitation']].copy()
# plot_df['prediction'] = rf_default_pred_val
# plot_df = plot_df.sort_values('observationTime')

plot_df = val.loc[y_val.index, ['observationTime', 'target_precipitation', 'tp']].copy()
plot_df['prediction'] = rf_default_pred_val
plot_df = plot_df.sort_values('observationTime')

# %%
fig, ax1 = plt.subplots(figsize=(15, 4))
ax1.plot(plot_df['observationTime'], plot_df['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
ax1.plot(plot_df['observationTime'], plot_df['tp'], label='ECMWF', color='green', linewidth=1.2, alpha=0.6)
ax1.plot(plot_df['observationTime'], plot_df['prediction'], label='Prognozė', color='blue', linewidth=1.2, alpha=0.55)
ax1.legend(loc='upper right', fontsize=10, frameon=True)
ax1.set_title("Kritulių prognozės palyginimas (Validavimo aibė)", fontsize=14)
ax1.set_xlabel("Laikas", fontsize=12)
ax1.set_ylabel("Kritulių kiekis", fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)

fig.tight_layout()
plt.show()

# %%
short_period = plot_df[(plot_df['observationTime'] >= '2024-05-01') & (plot_df['observationTime'] < '2024-09-01')]

fig, ax1 = plt.subplots(figsize=(15, 4))
ax1.plot(short_period['observationTime'], short_period['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
ax1.plot(short_period['observationTime'], short_period['tp'], label='ECMWF', color='green', linewidth=1.2, alpha=0.6)
ax1.plot(short_period['observationTime'], short_period['prediction'], label='Prognozė', color='blue', linewidth=1.2, alpha=0.6)
ax1.legend(loc='upper right', fontsize=10, frameon=True)
ax1.set_title("Kritulių prognozės palyginimas (Validavimo aibė)", fontsize=14)
ax1.set_xlabel("Laikas", fontsize=12)
ax1.set_ylabel("Kritulių kiekis", fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Požymių reikšmingumas

# %%
rf_default_importances = rf_default.feature_importances_
rf_default_importances
# Out:
# array([0.00696781, 0.00655472, 0.00563803, 0.00998937, 0.00927575,
#        0.02902097, 0.00470279, 0.00898971, 0.00806517, 0.482437  ,
#        0.00899315, 0.00782845, 0.00999985, 0.00578199, 0.00827684,
#        0.00937134, 0.0052599 , 0.00965836, 0.00808838, 0.0068126 ,
#        0.02636796, 0.00603728, 0.00350455, 0.01253554, 0.01215982,
#        0.01690873, 0.00708988, 0.00800348, 0.00974275, 0.00529623,
#        0.00679371, 0.00531256, 0.01060628, 0.01189252, 0.00904142,
#        0.0074317 , 0.01476983, 0.00989977, 0.00716229, 0.0067668 ,
#        0.00488093, 0.00803819, 0.00500767, 0.00751326, 0.01231178,
#        0.01671874, 0.01679826, 0.01131731, 0.00473333, 0.0063937 ,
#        0.00953101, 0.00916793, 0.00648847, 0.01319219, 0.00954338,
#        0.00932854])

# %%
result = permutation_importance(rf_default, X_val, y_val, n_repeats=5, random_state=123)
sorted_importances_idx = result.importances_mean.argsort()
importances_df = pd.DataFrame(
    result.importances[sorted_importances_idx].T,
    columns=X_val.columns[sorted_importances_idx]
)

forest_importances = pd.Series(result.importances_mean, index=X_val.columns)
forest_importances = forest_importances[forest_importances > 0]
forest_importances = forest_importances.sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(12, 6))
forest_importances.plot.barh(ax=ax, color='skyblue')
ax.set_title("Permutation Importance (mean)")
ax.set_xlabel("Mean decrease in accuracy score")
ax.axvline(x=0, color="k", linestyle="--")

fig.tight_layout()
plt.show()

# %%
forest_importances
# Out:
# windSpeed_fixed_lag-1                            0.000184
# NO2_slant_column_number_density_lag-1            0.000272
# stratospheric_NO2_column_number_density_lag-3    0.000278
# absorbing_aerosol_index_lag-8                    0.000457
# sia_window-11                                    0.000965
# airTemperature                                   0.001376
# windGust_fixed                                   0.001939
# absorbing_aerosol_index_window-8                 0.002024
# nh3_lag-11                                       0.002306
# xgb_cloudCover                                   0.002577
# windGust_fixed_lag-2                             0.002854
# feelsLikeTemperature_fixed                       0.003115
# NO2_column_number_density                        0.003532
# pm2p5                                            0.004496
# tropopause_pressure                              0.005151
# stratospheric_NO2_column_number_density_lag-7    0.006867
# missforest_precipitation                         0.008870
# airTemperature_lag-9                             0.010872
# windDirection_fixed_lag-10                       0.012293
# airTemperature_lag-10                            0.020552
# pm10                                             0.053813
# tp                                               0.763074
# dtype: float64

# %% [markdown]
# ## Optimalių hiperparametrų atrinkimas
#
# ### Hiperparametrų kitimas

# %%
# from sklearn.model_selection import validation_curve

# %%
# params = [
#     {"name": "n_estimators", "range": [10, 20, 50, 100, 200, 350, 400, 500]},
#     {"name": "max_depth", "range": [2, 4, 8, 16, 32, 64, 128]},
#     {"name": "max_features", "range": [0.05, 0.01,  0.1, 0.2, 0.3, 0.4, 0.6, 0.8, 1.0]},
#     {"name": "min_samples_split", "range": [2, 5, 10, 20, 50]}
# ]


# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# axes = axes.flatten()
# tscv = TimeSeriesSplit(n_splits=5)

# for i, p in enumerate(params):

#     rf = RandomForestRegressor(random_state=123)
    
#     train_scores, test_scores = validation_curve(
#         rf, X_train, y_train, 
#         param_name=p["name"], param_range=p["range"],
#         cv=tscv, scoring="neg_mean_squared_error", n_jobs=-1
#     )

#     train_mean = np.mean(train_scores, axis=1)
#     test_mean = np.mean(test_scores, axis=1)
    
#     axes[i].plot(p["range"], train_mean, label="Mokymo", marker='o', color='blue', markersize=3)
#     axes[i].plot(p["range"], test_mean, label="Validacijos", marker='s', color='orange', markersize=3)

#     axes[i].set_xlabel(f"Parametro '{p['name']}' reikšmė")
#     axes[i].set_ylabel("neg_mean_squared_error")
#     axes[i].grid(True, linestyle='--', alpha=0.7)
#     axes[i].legend()

# plt.tight_layout()
# plt.show()

# %%
# param_grid = {
#     'n_estimators': [50, 100, 150, 200],
#     'max_depth': [None, 4, 16, 32, 64], 
#     'min_samples_split': [2, 4, 6, 8],
#     'min_samples_leaf': [1, 2, 3, 4]
# }

# rf = RandomForestRegressor(random_state=123)

# tscv = TimeSeriesSplit(n_splits=5)
# grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=tscv)
# grid_search.fit(X_train, y_train)

# best_model = grid_search.best_estimator_

# print(f"Geriausi parametrai: {grid_search.best_params_}")
# print(f"Tikslumas: {grid_search.best_score_:.4f}")

# %%
# rf_h = RandomForestRegressor(max_depth = 4, n_estimators = 200, random_state=123)
# rf_h.fit(X_train, y_train)
# rf_h_pred_val = rf_h.predict(X_val)

# metrics_fun(y_val, rf_h_pred_val)

# %%
# rf_h = RandomForestRegressor(max_depth = 16, n_estimators = 50, min_samples_leaf = 3, min_samples_split = 2, random_state=123)
# rf_h.fit(X_train, y_train)
# rf_h_pred_val = rf_h.predict(X_val)

# metrics_fun(y_val, rf_h_pred_val)

# %% [markdown]
# ### Vizualizacija

# %%
# plot_df = val[['observationTime', 'target_precipitation']].copy()
# plot_df['prediction'] = rf_h_pred_val
# plot_df = plot_df.sort_values('observationTime')

# %%
# fig, ax1 = plt.subplots(figsize=(15, 4))
# ax1.plot(plot_df['observationTime'], plot_df['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
# ax1.plot(plot_df['observationTime'], plot_df['prediction'], label='Prognozė', color='blue', linewidth=1.2, alpha=0.6)
# ax1.legend(loc='upper right', fontsize=10, frameon=True)
# ax1.set_title("Kritulių prognozės palyginimas (Validavimo aibė)", fontsize=14)
# ax1.set_xlabel("Laikas", fontsize=12)
# ax1.set_ylabel("Kritulių kiekis", fontsize=12)
# ax1.grid(True, linestyle='--', alpha=0.5)

# fig.tight_layout()
# plt.show()
