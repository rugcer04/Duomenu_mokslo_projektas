# %% [markdown]
# # Bibliotekos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from scipy import stats

from sklearn.inspection import permutation_importance
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# %% [markdown]
# # Duomenys

# %%
data = pd.read_csv("../datasets_prep/dm_project_dataset.csv")
data['observationTime'] = pd.to_datetime(data['observationTime'])
data.columns
# Out:
# Index(['observationTime', 'absorbing_aerosol_index',
#        'NO2_column_number_density', 'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'tropopause_pressure',
#        'H2O_column_number_density', 'BrO', 'BrO_Error', 'NO2', 'NO2_Error',
#        'O3', 'O3_Error', 'pm10', 'pm2p5', 'sia', 'nmvoc', 'dust', 'nh3',
#        'pans', 'tp', 't2m', 'airTemperature', 'seaLevelPressure',
#        'relativeHumidity', 'missforest_precipitation', 'xgb_cloudCover',
#        'feelsLikeTemperature_fixed', 'windSpeed_fixed', 'windGust_fixed',
#        'windDirection_fixed'],
#       dtype='object')

# %%
data = data.drop(columns=['BrO_Error', 'NO2_Error', 'O3_Error', 't2m'])
data['month'] = data['observationTime'].dt.month
data['day_of_year'] = data['observationTime'].dt.dayofyear
data['day_of_week'] = data['observationTime'].dt.dayofweek

# %%
data.columns
# Out:
# Index(['observationTime', 'absorbing_aerosol_index',
#        'NO2_column_number_density', 'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'tropopause_pressure',
#        'H2O_column_number_density', 'BrO', 'NO2', 'O3', 'pm10', 'pm2p5', 'sia',
#        'nmvoc', 'dust', 'nh3', 'pans', 'tp', 'airTemperature',
#        'seaLevelPressure', 'relativeHumidity', 'missforest_precipitation',
#        'xgb_cloudCover', 'feelsLikeTemperature_fixed', 'windSpeed_fixed',
#        'windGust_fixed', 'windDirection_fixed', 'month', 'day_of_year',
#        'day_of_week'],
#       dtype='object')

# %%
data.head(5)
# Out:
#   observationTime  absorbing_aerosol_index  NO2_column_number_density  \
# 0      2018-07-01                -1.016247                   0.000075
# 1      2018-07-02                -0.800622                   0.000079
# 2      2018-07-03                -0.621235                   0.000077
# 3      2018-07-04                -0.659180                   0.000072
# 4      2018-07-05                -1.010234                   0.000079
#
#    stratospheric_NO2_column_number_density  NO2_slant_column_number_density  \
# 0                                 0.000062                         0.000193
# 1                                 0.000066                         0.000196
# 2                                 0.000062                         0.000203
# 3                                 0.000065                         0.000146
# 4                                 0.000067                         0.000198
#
#    tropopause_pressure  H2O_column_number_density           BrO           NO2  \
# 0            22057.926                1136.782022  4.376100e+13  3.627587e+15
# 1            22067.760                1229.531736  3.946727e+13  3.795988e+15
# 2            19219.670                1314.680602  4.465846e+13  4.526218e+15
# 3            19219.450                1824.427700  4.888972e+13  4.149200e+15
# 4            19218.373                1257.064200  4.093649e+13  3.959891e+15
#
#            O3  ...  relativeHumidity  missforest_precipitation  \
# 0  332.670633  ...         72.791667                       9.1
# 1  339.679410  ...         94.000000                      11.9
# 2  361.533268  ...         90.041667                      10.0
# 3  343.308865  ...         88.291667                      13.9
# 4  311.500626  ...         70.208333                       0.0
#
#    xgb_cloudCover  feelsLikeTemperature_fixed  windSpeed_fixed  \
# 0       89.375000                   10.933333         3.762500
# 1       91.500000                   10.429167         2.516667
# 2       89.375000                   13.387500         2.537500
# 3       88.333333                   13.591667         2.358333
# 4       66.000000                   16.291667         1.283333
#
#    windGust_fixed  windDirection_fixed  month  day_of_year  day_of_week
# 0            13.9                356.0      7          182            6
# 1             7.0                327.0      7          183            0
# 2             8.3                271.0      7          184            1
# 3             8.7                288.0      7          185            2
# 4             6.1                293.0      7          186            3
#
# [5 rows x 30 columns]

# %% [markdown]
# # Random Forest realizacija

# %% [markdown]
# ## Požymių sukūrimas

# %% [markdown]
# ### Vėlavimai

# %%
def lags_fun(column_name, lag_value, data):
    
    new_col_name = f"{column_name}_lag-{lag_value}"
    data.loc[:, new_col_name] = data[column_name].shift(lag_value)

# %%
lags_info = {
    # DALELES
    # 'absorbing_aerosol_index': [8, 19],
    'absorbing_aerosol_index': [8],
    # 'NO2_column_number_density': [1, 2, 3],
    'NO2_column_number_density': [1],
    # 'stratospheric_NO2_column_number_density': [1, 3, 7],
    # 'NO2_slant_column_number_density': [1, 2],
    # 'tropopause_pressure': [1],
    # 'H2O_column_number_density': [1, 2],
    # 'NO2': [1, 4, 9],
    'NO2': [1],
    # 'dust': [1, 4],
    # 'sia': [11]
    # 'pm2p5': [1, 11],
    # 'pans': [10, 18],
    # 'nmvoc': [1, 2],
    'nmvoc': [1],
    # 'nh3': [1, 11],
    'nh3': [1],
    # 'pm10': [1, 11],
    'pm10': [1],

    # # METEO
    # 'airTemperature': [1, 3, 9, 10],
    # 'seaLevelPressure': [1, 2],
    'seaLevelPressure': [1],
    # 'relativeHumidity': [1, 2],
    # 'xgb_cloudCover': [1, 2],
    # 'windSpeed_fixed': [1, 2, 3],
    # 'windGust_fixed': [1, 2],
    # 'windDirection_fixed': [4, 10]
}

for col, lags in lags_info.items():
    if isinstance(lags, list):
        for lag in lags:
            lags_fun(col, lag, data)
    else:
        lags_fun(col, lags, data)

# %%
data['target_precipitation'] = data['missforest_precipitation'].shift(-1)

# %% [markdown]
# ### Rolling window

# %%
def rolling_window_fun(column_name, window_value, data):

    new_col_name = f"{column_name}_window-{window_value}"
    data.loc[:, new_col_name] = data[column_name].rolling(window=window_value).mean().shift(1)
    # data.loc[:, new_col_name] = data[column_name].rolling(window=window_value).mean()

# %%
window_info = {
    # 'absorbing_aerosol_index': [8],
    # 'NO2_column_number_density': [3, 2],
    # 'stratospheric_NO2_column_number_density': [3, 5, 7],
    # 'NO2_slant_column_number_density': [2],
    # 'tropopause_pressure': [2],
    # 'H2O_column_number_density': [3],
    # 'NO2': [3, 5, 7],
    # 'dust': [4, 6, 8],
    # 'dust': [5],
    # 'sia': [11],
    # 'pm2p5': [11],
    # 'pm2p5': [2],
    # 'pans': [11],
    # 'nmvoc': [3, 5],
    # 'nmvoc': [5],
    # 'nh3': [2, 4],
    # 'nh3': [12],
    # 'pm10': [2]

    # 'airTemperature': [4, 11],
    # 'seaLevelPressure': [3, 7],
    # 'seaLevelPressure': [7],
    # 'relativeHumidity': [3, 5],
    # 'xgb_cloudCover': [3, 5],
    # 'windSpeed_fixed': [4],
    # 'windGust_fixed': [3],
    # 'windDirection_fixed': [11]
}

for col, windows in window_info.items():
    if isinstance(windows, list):
        for window in windows:
            rolling_window_fun(col, window, data)
    else:
        rolling_window_fun(col, windows, data)

# %%
data_clean = data.dropna()

# %%
# data_clean['after_aai'] = (data['observationTime'] >= pd.to_datetime('2021-07-01')).astype(int)

# %%
data_clean.columns
# Out:
# Index(['observationTime', 'absorbing_aerosol_index',
#        'NO2_column_number_density', 'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'tropopause_pressure',
#        'H2O_column_number_density', 'BrO', 'NO2', 'O3', 'pm10', 'pm2p5', 'sia',
#        'nmvoc', 'dust', 'nh3', 'pans', 'tp', 'airTemperature',
#        'seaLevelPressure', 'relativeHumidity', 'missforest_precipitation',
#        'xgb_cloudCover', 'feelsLikeTemperature_fixed', 'windSpeed_fixed',
#        'windGust_fixed', 'windDirection_fixed', 'month', 'day_of_year',
#        'day_of_week', 'absorbing_aerosol_index_lag-8',
#        'NO2_column_number_density_lag-1', 'NO2_lag-1', 'nmvoc_lag-1',
#        'nh3_lag-1', 'pm10_lag-1', 'seaLevelPressure_lag-1',
#        'target_precipitation'],
#       dtype='object')

# %% [markdown]
# ## Požymių atrinkimas

# %% [markdown]
# ### Požymiai atrinkti pagal algoritmo kintamųjų svarbą

# %%
# Modelio atrinkti požymiai iš originalios aibės
models_selected_features = ['tp', 'pm10', 'missforest_precipitation', 'H2O_column_number_density', 'nh3', 'tropopause_pressure',
                            'windGust_fixed', 'day_of_year', 'NO2_column_number_density', 'xgb_cloudCover', 'absorbing_aerosol_index', 
                            'pans', 'month', 'stratospheric_NO2_column_number_density', 'NO2_slant_column_number_density',
                            'feelsLikeTemperature_fixed', 'sia']

models_selected_features_lag = ['tp', 'pm10', 'missforest_precipitation', 'H2O_column_number_density', 'nh3', 'tropopause_pressure',
                                'windGust_fixed', 'day_of_year', 'NO2_column_number_density', 'xgb_cloudCover', 'absorbing_aerosol_index', 
                                'pans', 'month', 'stratospheric_NO2_column_number_density', 'NO2_slant_column_number_density',
                                'feelsLikeTemperature_fixed', 'sia', 
                                'absorbing_aerosol_index_lag-8', 'NO2_column_number_density_lag-1', 
                                'NO2_lag-1', 'nmvoc_lag-1', 'nh3_lag-1', 'pm10_lag-1', 'seaLevelPressure_lag-1']

models_selected_features_lag_im = ['tp', 'pm10', 'NO2_lag-1', 'H2O_column_number_density', 'pm10_lag-1', 'missforest_precipitation',
                                   'feelsLikeTemperature_fixed', 'xgb_cloudCover', 'windGust_fixed', 'sia', 'nh3', 'day_of_year', 
                                   'tropopause_pressure', 'nmvoc_lag-1', 'NO2_column_number_density_lag-1', 'stratospheric_NO2_column_number_density',
                                   'NO2_column_number_density', 'nh3_lag-1', 'NO2_slant_column_number_density', 'absorbing_aerosol_index', 'pans']


# Modelio atrinkti požymiai iš originalios aibės, lagų ir rolling windows
models_selected_features_full = ['tp', 'pm10', 'airTemperature_lag-10', 'windDirection_fixed_lag-10', 'airTemperature_lag-9', 'tropopause_pressure',
                              'xgb_cloudCover', 'stratospheric_NO2_column_number_density_lag-7', 'pm2p5', 'NO2_lag-9', 'missforest_precipitation',
                              'day_of_year', 'windSpeed_fixed_lag-1', 'NO2_slant_column_number_density_lag-2', 'NO2_slant_column_number_density_lag-1',
                              'pm2p5_window-11', 'nh3_window-2', 'relativeHumidity', 'NO2_column_number_density_window-3', 'NO2_column_number_density',
                              'sia_window-11', 'airTemperature', 'BrO', 'stratospheric_NO2_column_number_density', 'feelsLikeTemperature_fixed',
                              'nmvoc_lag-1', 'absorbing_aerosol_index_window-8', 'windGust_fixed_lag-2', 'NO2_column_number_density_lag-3', 'nh3',
                              'xgb_cloudCover_lag-1', 'dust_lag-4', 'sia_lag-11', 'NO2_column_number_density_lag-1', 'NO2_lag-1', 'dust', 'pans_lag-18',
                              'NO2_slant_column_number_density']

# Modelio atrinkti požymiai iš originalios aibės, lagų ir rolling windows PART2
models_selected_features_full_2 = ['tp', 'pm10', 'airTemperature_lag-10', 'xgb_cloudCover', 'missforest_precipitation', 'stratospheric_NO2_column_number_density_lag-7',
                              'windDirection_fixed_lag-10', 'airTemperature_lag-9', 'sia_window-11', 'NO2_column_number_density_lag-1', 'pm2p5', 'day_of_year',
                              'feelsLikeTemperature_fixed', 'tropopause_pressure', 'windGust_fixed_lag-2', 'NO2_column_number_density', 'NO2_column_number_density_window-3',
                              'airTemperature', 'BrO', 'nh3', 'NO2_lag-9', 'dust_lag-4', 'nmvoc_lag-1', 'relativeHumidity', 'nh3_window-2', 'xgb_cloudCover_lag-1',
                              'NO2_lag-1', 'pm2p5_window-11', 'pans_lag-18']

# %%
data_clean = data_clean[models_selected_features_lag + ['observationTime', 'target_precipitation']].copy()

# %% [markdown]
# ### Aibių sudarymas

# %%
train_end = '2024-02-01'
val_end = '2025-02-01'

train = data_clean[data_clean['observationTime'] < train_end]
val = data_clean[(data_clean['observationTime'] >= train_end) & (data_clean['observationTime'] <= val_end)]
test  = data_clean[data_clean['observationTime'] > val_end]

print(f"Train: {train.shape}, nuo {train['observationTime'].min()} iki {train['observationTime'].max()}")
print(f"Val: {val.shape}, nuo {val['observationTime'].min()} iki {val['observationTime'].max()}")
print(f"Test:  {test.shape},  nuo {test['observationTime'].min()} iki {test['observationTime'].max()}")
# Out:
# Train: (2033, 26), nuo 2018-07-09 00:00:00 iki 2024-01-31 00:00:00
# Val: (367, 26), nuo 2024-02-01 00:00:00 iki 2025-02-01 00:00:00
# Test:  (363, 26),  nuo 2025-02-02 00:00:00 iki 2026-01-30 00:00:00

# %%
target = 'target_precipitation'
drop_cols = ['observationTime', target]

X_train = train.drop(columns=drop_cols)
y_train = train[target]

X_val = val.drop(columns=drop_cols)
y_val = val[target]

X_test = test.drop(columns=drop_cols)
y_test = test[target]

# %% [markdown]
# ### Realizacija

# %%
X_train.columns
# Out:
# Index(['tp', 'pm10', 'missforest_precipitation', 'H2O_column_number_density',
#        'nh3', 'tropopause_pressure', 'windGust_fixed', 'day_of_year',
#        'NO2_column_number_density', 'xgb_cloudCover',
#        'absorbing_aerosol_index', 'pans', 'month',
#        'stratospheric_NO2_column_number_density',
#        'NO2_slant_column_number_density', 'feelsLikeTemperature_fixed', 'sia',
#        'absorbing_aerosol_index_lag-8', 'NO2_column_number_density_lag-1',
#        'NO2_lag-1', 'nmvoc_lag-1', 'nh3_lag-1', 'pm10_lag-1',
#        'seaLevelPressure_lag-1'],
#       dtype='object')

# %%
rf_default = RandomForestRegressor(random_state=123)
rf_default.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=123)

# %%
rf_default_pred = rf_default.predict(X_val)

# %% [markdown]
# ### Metrikos

# %%
def metrics_fun(y_val_true, rf_pred_val):
    print(f'R^2:  {r2_score(y_val_true, rf_pred_val)}')
    print(f'MAE:  {mean_absolute_error(y_val_true, rf_pred_val)}')
    print(f'RMSE: {np.sqrt(mean_squared_error(y_val_true, rf_pred_val))}')
    # print(f'MAPE: {mean_absolute_percentage_error(y_val_true, rf_pred_val)}')

    corr, p_value = stats.spearmanr(y_val_true, rf_pred_val)
    print(f"r_s:  {corr}")

# %% [markdown]
# Globalaus modelio paklaidos - validavimo aibė

# %%
metrics_fun(y_val, X_val['tp'])
# Out:
# R^2:  0.5026324749895323
# MAE:  1.4685700168000633
# RMSE: 3.40532484561435
# r_s:  0.7378103776223065

# %% [markdown]
# RF modelio paklaidos

# %%
metrics_fun(y_val, rf_default_pred)
# Out:
# R^2:  0.5558513649600921
# MAE:  1.382936576720744
# RMSE: 3.217984888762259
# r_s:  0.716700513571682

# %%
# be aai
# R^2:  0.5558513649600921
# MAE:  1.382936576720744
# RMSE: 3.217984888762259
# r_s:  0.716700513571682

# su aai:
# R^2:  0.5482813805217108
# MAE:  1.3763725799907744
# RMSE: 3.2452923841055745
# r_s:  0.7185493781021143

# %%
len(rf_default_pred)
# Out:
# 367

# %% [markdown]
# ### Vizualizacija

# %%
plot_df = val.loc[y_val.index, ['observationTime', 'target_precipitation', 'tp']].copy()
plot_df['prediction'] = rf_default_pred
plot_df = plot_df.sort_values('observationTime')

# %%
fig, ax1 = plt.subplots(figsize=(15, 4))
ax1.plot(plot_df['observationTime'], plot_df['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
ax1.plot(plot_df['observationTime'], plot_df['tp'], label='ECMWF', color='green', linewidth=1.2, alpha=0.6)
ax1.plot(plot_df['observationTime'], plot_df['prediction'], label='Prognozė', color='blue', linewidth=1.1, alpha=0.55)
ax1.legend(loc='upper right', fontsize=10, frameon=True)
ax1.set_title("Kritulių prognozės palyginimas (Validavimo aibė)", fontsize=14)
ax1.set_xlabel("Laikas", fontsize=12)
ax1.set_ylabel("Kritulių kiekis", fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)

fig.tight_layout()
plt.show()

# %%
short_period = plot_df[(plot_df['observationTime'] >= '2024-05-01') & (plot_df['observationTime'] < '2024-09-01')]

fig, ax1 = plt.subplots(figsize=(15, 4))
ax1.plot(short_period['observationTime'], short_period['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
ax1.plot(short_period['observationTime'], short_period['tp'], label='ECMWF', color='green', linewidth=1.2, alpha=0.6)
ax1.plot(short_period['observationTime'], short_period['prediction'], label='Prognozė', color='blue', linewidth=1.2, alpha=0.6)
ax1.legend(loc='upper right', fontsize=10, frameon=True)
ax1.set_title("Kritulių prognozės palyginimas (Validavimo aibė)", fontsize=14)
ax1.set_xlabel("Laikas", fontsize=12)
ax1.set_ylabel("Kritulių kiekis", fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Požymių reikšmingumas

# %%
rf_default_importances = rf_default.feature_importances_
rf_default_importances
# Out:
# array([0.51982801, 0.04661398, 0.01839122, 0.04023671, 0.01606888,
#        0.0168887 , 0.02117826, 0.01375396, 0.01258783, 0.0177821 ,
#        0.01709221, 0.0149041 , 0.00223043, 0.02141055, 0.01034343,
#        0.03769726, 0.01134611, 0.03226941, 0.01878764, 0.02094422,
#        0.01958179, 0.02141397, 0.03375697, 0.01489223])

# %%
result = permutation_importance(rf_default, X_val, y_val, n_repeats=5, random_state=123)
sorted_importances_idx = result.importances_mean.argsort()
importances_df = pd.DataFrame(
    result.importances[sorted_importances_idx].T,
    columns=X_val.columns[sorted_importances_idx]
)

forest_importances = pd.Series(result.importances_mean, index=X_val.columns)
forest_importances = forest_importances[forest_importances > 0]
forest_importances = forest_importances.sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(12, 6))
forest_importances.plot.barh(ax=ax, color='skyblue')
ax.set_title("Permutation Importance (mean)")
ax.set_xlabel("Mean decrease in accuracy score")
ax.axvline(x=0, color="k", linestyle="--")

fig.tight_layout()
plt.show()

# %%
forest_importances
# Out:
# pans                                       0.000159
# absorbing_aerosol_index                    0.000342
# NO2_slant_column_number_density            0.000715
# nh3_lag-1                                  0.003896
# NO2_column_number_density                  0.004837
# stratospheric_NO2_column_number_density    0.004875
# NO2_column_number_density_lag-1            0.004909
# nmvoc_lag-1                                0.005862
# tropopause_pressure                        0.006599
# day_of_year                                0.007199
# nh3                                        0.007392
# sia                                        0.007844
# windGust_fixed                             0.008952
# xgb_cloudCover                             0.009774
# feelsLikeTemperature_fixed                 0.011053
# missforest_precipitation                   0.011886
# pm10_lag-1                                 0.014975
# H2O_column_number_density                  0.019262
# NO2_lag-1                                  0.026076
# pm10                                       0.057486
# tp                                         0.903516
# dtype: float64

# %% [markdown]
# ## Optimalių hiperparametrų atrinkimas
#
# ### Hiperparametrų kitimas

# %%
from sklearn.model_selection import validation_curve
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# %%
params = [
    {"name": "n_estimators", "range": [10, 20, 50, 100, 200, 350, 400, 500]},
    {"name": "max_depth", "range": [2, 4, 8, 16, 32, 64, 128]},
    {"name": "max_features", "range": [0.1, 0.2, 0.3, 0.4, 0.6, 0.8, 1.0]},
    {"name": "min_samples_split", "range": [2, 5, 10, 20, 50, 80, 100]},
    {"name": "min_samples_leaf", "range": [1, 2, 3, 4, 5]}
]


fig, axes = plt.subplots(3, 2, figsize=(15, 10))
axes = axes.flatten()
tscv = TimeSeriesSplit(n_splits=5)

for i, p in enumerate(params):

    rf = RandomForestRegressor(random_state=123)
    
    train_scores, test_scores = validation_curve(
        rf, X_train, y_train, 
        param_name=p["name"], param_range=p["range"],
        cv=tscv, scoring="neg_mean_squared_error", n_jobs=-1
    )

    train_mean = np.mean(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    
    axes[i].plot(p["range"], train_mean, label="Mokymo", marker='o', color='blue', markersize=3)
    axes[i].plot(p["range"], test_mean, label="Validacijos", marker='s', color='orange', markersize=3)

    axes[i].set_xlabel(f"Parametro '{p['name']}' reikšmė")
    axes[i].set_ylabel("neg_mean_squared_error")
    axes[i].grid(True, linestyle='--', alpha=0.7)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
# def huber_loss_func(y_true, y_pred, delta=1.0):
#     error = y_true - y_pred
#     is_small_error = np.abs(error) <= delta
#     squared_loss = 0.5 * np.power(error, 2)
#     linear_loss = delta * (np.abs(error) - 0.5 * delta)
#     return np.where(is_small_error, squared_loss, linear_loss).mean()

# huber_scorer = make_scorer(huber_loss_func, greater_is_better=False, delta=1.0)

# %%
param_grid = {
    'n_estimators':      [50, 100, 200],
    'max_depth':         [8, 12, 16, 20, 24, 28, 32, None],
    'max_features':      [0.5, 0.6, 0.7, 0.8, 0.9],
    'min_samples_leaf':  [1, 2, 4],
    'min_samples_split': [2, 3, 5, 7],
    'max_samples':       [0.6, 0.7, 0.8, 0.9, None]
}

tscv = TimeSeriesSplit(n_splits=5)

grid_search = GridSearchCV(
    estimator=RandomForestRegressor(random_state=123, n_jobs=-1), param_grid=param_grid, cv=tscv,
    scoring='neg_root_mean_squared_error', return_train_score=True)

grid_search.fit(X_train, y_train)

print(f"\nGeriausi parametrai: {grid_search.best_params_}")
print(f"Geriausias CV RMSE: {-grid_search.best_score_:.4f}")

best_model = grid_search.best_estimator_
# Out:
# Geriausi parametrai: {'max_depth': 16, 'max_features': 0.7, 'max_samples': 0.9, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# Geriausias CV RMSE: 3.5889

# %%
best_GS_model = RandomForestRegressor(max_depth=16, max_features=0.7, max_samples=0.9, min_samples_leaf=2,
                                      min_samples_split=5, n_estimators=50, random_state=123)
best_GS_model.fit(X_train, y_train)
best_pred_val = best_GS_model.predict(X_val)
print("-- Validavimo aibė --")
metrics_fun(y_val, best_pred_val)
# Out:
# -- Validavimo aibė --
# R^2:  0.4837942299150122
# MAE:  1.4240960404963956
# RMSE: 3.4692153702841337
# r_s:  0.7262301588201123

# %%
default_pred_val = rf_default.predict(X_val)
print("-- Validavimo aibė --")
metrics_fun(y_val, default_pred_val)
# Out:
# -- Validavimo aibė --
# R^2:  0.5558513649600921
# MAE:  1.382936576720744
# RMSE: 3.217984888762259
# r_s:  0.716700513571682

# %% [markdown]
# Pagal validavimo aibę geriausias modelis yra naudojantis numatytaisiais hiperparametrais

# %% [markdown]
# ## Testavimo aibės rezultatai
#
# ### Metrikos
#
# Globalaus

# %%
metrics_fun(y_test, X_test['tp'])
# Out:
# R^2:  0.49064675292448867
# MAE:  1.4333678202939222
# RMSE: 3.1415679902213944
# r_s:  0.7629911314397974

# %% [markdown]
# RF

# %%
best_pred_test = rf_default.predict(X_test)
metrics_fun(y_test, best_pred_test)
# Out:
# R^2:  0.553828208315136
# MAE:  1.3877199628900454
# RMSE: 2.9402751833516927
# r_s:  0.7290049001498066

# %% [markdown]
# ### Vizualizacija

# %%
plot_test_df = test.loc[y_test.index, ['observationTime', 'target_precipitation', 'tp']].copy()
plot_test_df['prediction'] = best_pred_test
plot_test_df = plot_test_df.sort_values('observationTime')

# %%
fig, ax1 = plt.subplots(figsize=(15, 4))
ax1.plot(plot_test_df['observationTime'], plot_test_df['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
ax1.plot(plot_test_df['observationTime'], plot_test_df['tp'], label='ECMWF', color='green', linewidth=1.2, alpha=0.6)
ax1.plot(plot_test_df['observationTime'], plot_test_df['prediction'], label='Prognozė', color='blue', linewidth=1.1, alpha=0.55)
ax1.legend(loc='upper right', fontsize=10, frameon=True)
ax1.set_title("Kritulių prognozės palyginimas (testavimo aibė)", fontsize=14)
ax1.set_xlabel("Laikas", fontsize=12)
ax1.set_ylabel("Kritulių kiekis", fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)

fig.tight_layout()
plt.show()

# %%
short_period = plot_test_df[(plot_test_df['observationTime'] >= '2025-11-01') & (plot_test_df['observationTime'] <= '2026-01-30')]
# nuo 2025-02-02 00:00:00 iki 2026-01-30 00:00:00
fig, ax1 = plt.subplots(figsize=(15, 4))
ax1.plot(short_period['observationTime'], short_period['target_precipitation'], label='Tikros reikšmės', color='red', linewidth=1.2, alpha=0.6)
ax1.plot(short_period['observationTime'], short_period['tp'], label='ECMWF', color='green', linewidth=1.2, alpha=0.6)
ax1.plot(short_period['observationTime'], short_period['prediction'], label='Prognozė', color='blue', linewidth=1.2, alpha=0.6)
ax1.legend(loc='upper right', fontsize=10, frameon=True)
ax1.set_title("Kritulių prognozės palyginimas (testavimo aibė: sausis ir vasaris)", fontsize=14)
ax1.set_xlabel("Laikas", fontsize=12)
ax1.set_ylabel("Kritulių kiekis", fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Prognozių įrašymas

# %%
prediction1 = pd.DataFrame(data = {'observationTime': val['observationTime'] + pd.Timedelta(days=1), 'rf_prediction': rf_default_pred, 'actual':val['target_precipitation'].values, 'ECMWF':val['tp'].values})
prediction2 = pd.DataFrame(data = {'observationTime': test['observationTime'] + pd.Timedelta(days=1), 'rf_prediction': best_pred_test, 'actual':test['target_precipitation'].values, 'ECMWF':test['tp'].values})
pd.concat([prediction1, prediction2]).to_csv('RF_prediction.csv', index=False)
